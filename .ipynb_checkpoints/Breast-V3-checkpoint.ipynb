# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("breast.csv")

# %%
df.info() #check if there is missing data (null value)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
dataset = df.iloc[:, :-1] #drop the last column (error coloumn)

# %%
dataset.drop(labels='id', axis=1,inplace=True) #drop the id, because we don't need this, and no has no usefull and meaning for prediction

# %%
dataset["diagnosis"].value_counts() # imbalance data
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
######### VISUALIZATION #################

# %%
#Ploting relationship between radius_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "radius_mean", hist=False, rug=True)

# %%
#Ploting relationship between texture_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "texture_mean", hist=True, rug=True)

# %%
#Ploting relationship between perimeter_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "perimeter_mean", hist=True, rug=True)

# %%
#Ploting relationship between area_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "area_mean", hist=True, rug=True)

# %%
#Ploting relationship between smoothness_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "smoothness_mean", hist=True, rug=True)

# %%
#Ploting relationship between compactness_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "compactness_mean", hist=True, rug=True)

# %%
#Ploting relationship between concavity_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "concavity_mean", hist=True, rug=True)

# %%
#Ploting relationship between concave point_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "concave points_mean", hist=True, rug=True)

# %%
#Ploting relationship between symetry_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "symmetry_mean", hist=True, rug=True)

# %%
#Ploting relationship between fractal_dimension_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "fractal_dimension_mean", hist=True, rug=True)

# %%
### It seems almost all data approximately symetry (base on display for each features), therefore no need to log

# %%
#sns.pairplot(df,hue="diagnosis",vars = ["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean"])

# %%
## Looking for correlation between each features


#Explore correlations
#plt.rcParams['figure.figsize']=(15,20)
#sns.set(font_scale=1.4)
#sns.heatmap(df.drop('diagnosis', axis=1).drop('id',axis=1).corr(), cmap='coolwarm',annot=True)

# %%
Y = pd.get_dummies(dataset["diagnosis"],drop_first=True)  #convert Malign to 1 and Benign to 0

# %%
Y.rename(columns={"M": "target"},inplace=True)  #rename for convinient name only
Y.head()
# Out:
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
X = dataset.drop(labels='diagnosis', axis=1) #drop the diagnosis,because we have changed B/M to M's coloumn (numerical_number)

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
df_norm = (X - X.mean()) / (X.max() - X.min())
X_norm = df_norm.copy()
Y_norm = Y.copy()
df_norm = pd.concat([df_norm, Y], axis=1)

# %%
df_norm.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.182815     -0.301307        0.213053   0.146813         0.198968
# 1     0.304923     -0.051392        0.282848   0.284671        -0.104905
# 2     0.263274      0.066295        0.262808   0.232497         0.119524
# 3    -0.128132      0.036874       -0.099434  -0.114014         0.416536
# 4     0.291671     -0.167388        0.298051   0.272369         0.035567
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.531437        0.495081             0.487976       0.306758
# 1         -0.078833       -0.004450             0.105621       0.000193
# 2          0.170416        0.254453             0.392549       0.129991
# 3          0.550761        0.357546             0.279726       0.396657
# 4          0.087292        0.255859             0.275253      -0.001323
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.335139  ...      -0.222474         0.385173    0.279792
# 1               -0.129057  ...      -0.060427         0.256680    0.264308
# 2               -0.059132  ...      -0.003924         0.225304    0.203602
# 3                0.729621  ...       0.021929        -0.041791   -0.076898
# 4               -0.083564  ...      -0.240065         0.223810    0.170669
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0          0.196998           0.399079         0.351207              0.518192
# 1         -0.056585          -0.065649        -0.024432              0.245339
# 2          0.079452           0.165163         0.142341              0.441216
# 3          0.511335           0.593799         0.331239              0.491044
# 4          0.033226          -0.047797         0.102086              0.164583
#
#    symmetry_worst  fractal_dimension_worst  target
# 0        0.335156                 0.229268       1
# 1       -0.029717                 0.033282       1
# 2        0.140399                 0.023837       1
# 3        0.736693                 0.584115       1
# 4       -0.105806                -0.047001       1
#
# [5 rows x 31 columns]

# %%
X_norm
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.182815     -0.301307        0.213053   0.146813         0.198968
# 1       0.304923     -0.051392        0.282848   0.284671        -0.104905
# 2       0.263274      0.066295        0.262808   0.232497         0.119524
# 3      -0.128132      0.036874       -0.099434  -0.114014         0.416536
# 4       0.291671     -0.167388        0.298051   0.272369         0.035567
# ..           ...           ...             ...        ...              ...
# 564     0.351778      0.104848        0.345733   0.349570         0.132163
# 565     0.284098      0.303022        0.271101   0.257099         0.012997
# 566     0.117029      0.297273        0.112853   0.086198        -0.106620
# 567     0.306342      0.339545        0.332603   0.258796         0.193552
# 568    -0.301353      0.177557       -0.304395  -0.201013        -0.394785
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            0.531437        0.495081             0.487976       0.306758
# 1           -0.078833       -0.004450             0.105621       0.000193
# 2            0.170416        0.254453             0.392549       0.129991
# 3            0.550761        0.357546             0.279726       0.396657
# 4            0.087292        0.255859             0.275253      -0.001323
# ..                ...             ...                  ...            ...
# 564          0.035455        0.363404             0.447221      -0.043242
# 565         -0.002886        0.129336             0.243493      -0.030110
# 566         -0.006260        0.008694             0.020382      -0.111929
# 567          0.529596        0.615278             0.512330       0.295647
# 568         -0.186249       -0.208058            -0.243137      -0.113444
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  0.335139  ...      0.324113      -0.222474
# 1                 -0.129057  ...      0.310239      -0.060427
# 2                 -0.059132  ...      0.259723      -0.003924
# 3                  0.729621  ...     -0.048353       0.021929
# 4                 -0.083564  ...      0.223081      -0.240065
# ..                      ...  ...           ...            ...
# 564               -0.138324  ...      0.326603       0.019264
# 565               -0.157279  ...      0.263992       0.335095
# 566               -0.133058  ...      0.096436       0.225021
# 567                0.155063  ...      0.336920       0.366279
# 568               -0.083353  ...     -0.242376       0.125074
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           0.385173    0.279792          0.196998           0.399079
# 1           0.256680    0.264308         -0.056585          -0.065649
# 2           0.225304    0.203602          0.079452           0.165163
# 3          -0.041791   -0.076898          0.511335           0.593799
# 4           0.223810    0.170669          0.033226          -0.047797
# ..               ...         ...               ...                ...
# 564         0.293036    0.281758          0.056999          -0.041685
# 565         0.237755    0.209009         -0.104131          -0.060216
# 566         0.096812    0.059825         -0.121961           0.053492
# 567         0.385173    0.231129          0.215488           0.595546
# 568        -0.239560   -0.150409         -0.280054          -0.184169
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.351207              0.518192        0.335156
# 1          -0.024432              0.245339       -0.029717
# 2           0.142341              0.441216        0.140399
# 3           0.331239              0.491044        0.736693
# 4           0.102086              0.164583       -0.105806
# ..               ...                   ...             ...
# 564         0.110632              0.367676       -0.165731
# 565         0.039386              0.165614       -0.064805
# 566         0.054402              0.093449       -0.134586
# 567         0.532357              0.516817        0.233835
# 568        -0.217403             -0.393836       -0.005866
#
#      fractal_dimension_worst
# 0                   0.229268
# 1                   0.033282
# 2                   0.023837
# 3                   0.584115
# 4                  -0.047001
# ..                       ...
# 564                -0.083929
# 565                -0.115281
# 566                -0.037687
# 567                 0.262719
# 568                -0.088914
#
# [569 rows x 30 columns]

# %%
Y_norm
# Out:
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 564       1
# 565       1
# 566       1
# 567       1
# 568       0
#
# [569 rows x 1 columns]

# %%
#Balancing data 
from imblearn.over_sampling import SMOTE

sm =SMOTE(random_state=42)
X_res , Y_res = sm.fit_resample(X_norm,Y_norm)
# Out:
# Using TensorFlow backend.

# %%
my_dataset = X_res.copy()

# %%
my_dataset=pd.concat([my_dataset, Y_res], axis=1)

# %%
my_dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.182815     -0.301307        0.213053   0.146813         0.198968
# 1     0.304923     -0.051392        0.282848   0.284671        -0.104905
# 2     0.263274      0.066295        0.262808   0.232497         0.119524
# 3    -0.128132      0.036874       -0.099434  -0.114014         0.416536
# 4     0.291671     -0.167388        0.298051   0.272369         0.035567
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.531437        0.495081             0.487976       0.306758
# 1         -0.078833       -0.004450             0.105621       0.000193
# 2          0.170416        0.254453             0.392549       0.129991
# 3          0.550761        0.357546             0.279726       0.396657
# 4          0.087292        0.255859             0.275253      -0.001323
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.335139  ...      -0.222474         0.385173    0.279792
# 1               -0.129057  ...      -0.060427         0.256680    0.264308
# 2               -0.059132  ...      -0.003924         0.225304    0.203602
# 3                0.729621  ...       0.021929        -0.041791   -0.076898
# 4               -0.083564  ...      -0.240065         0.223810    0.170669
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0          0.196998           0.399079         0.351207              0.518192
# 1         -0.056585          -0.065649        -0.024432              0.245339
# 2          0.079452           0.165163         0.142341              0.441216
# 3          0.511335           0.593799         0.331239              0.491044
# 4          0.033226          -0.047797         0.102086              0.164583
#
#    symmetry_worst  fractal_dimension_worst  target
# 0        0.335156                 0.229268       1
# 1       -0.029717                 0.033282       1
# 2        0.140399                 0.023837       1
# 3        0.736693                 0.584115       1
# 4       -0.105806                -0.047001       1
#
# [5 rows x 31 columns]

# %%
np.random.seed(15)
shuffle_df = my_dataset.reindex(np.random.permutation(my_dataset.index))

# %%
shuffle_df.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 341    -0.213985     -0.082842       -0.209585  -0.158808        -0.104273
# 593     0.073408      0.004810        0.058601   0.046649        -0.164099
# 581     0.126147      0.031437        0.110324   0.092340        -0.156182
# 301    -0.078910      0.020303       -0.079739  -0.077874        -0.106981
# 380    -0.135231     -0.214056       -0.129977  -0.113930         0.246815
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 341         -0.036995       -0.010729            -0.129220       0.113324
# 593         -0.144882       -0.110271            -0.103334      -0.124091
# 581         -0.100009       -0.097752            -0.079322       0.046526
# 301         -0.009021       -0.048030            -0.089111      -0.015464
# 380          0.020732       -0.022960             0.032708       0.104233
#
#      fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 341                0.178020  ...      -0.069489        -0.179348   -0.129518
# 593               -0.177807  ...       0.151105         0.046616    0.028031
# 581               -0.207978  ...       0.010618         0.104113    0.059928
# 301               -0.006479  ...      -0.069489        -0.095280   -0.080929
# 380                0.133580  ...      -0.137186        -0.111217   -0.099411
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 341         -0.059886           0.084733         0.129322
# 593         -0.161415          -0.064541        -0.035795
# 581         -0.186202          -0.008019        -0.033523
# 301         -0.180734          -0.037319        -0.065326
# 380          0.189074          -0.011026        -0.037930
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  target
# 341             -0.114798        0.016015                 0.093823       0
# 593             -0.099035       -0.018055                -0.099393       1
# 581             -0.069090        0.261484                -0.074889       1
# 301             -0.131808       -0.042530                -0.041360       0
# 380              0.059085        0.087176                 0.053812       0
#
# [5 rows x 31 columns]

# %%
shuffle_df["target"].value_counts() # already balance
# Out:
# 1    357
# 0    357
# Name: target, dtype: int64

# %%
#n_train 
#80% for train
#10% for validation
#10% for testing
ukuran_train=0.8
ukuran_validation=0.10

total = len(shuffle_df)
n_train = int (ukuran_train*total)
n_validation = int (ukuran_validation*total)
n_test = total-n_train-n_validation

#print (total)
#print (n_train)
#print (n_validation)
#print (n_test)

# %%
#split train_test
df_train = shuffle_df[0:n_train]
df_valid = shuffle_df[n_train:n_train+n_validation]
df_test= shuffle_df[n_train+n_validation:]

X_train = df_train.drop(labels='target', axis=1)
Y_train = df_train["target"]

X_validation = df_valid.drop(labels='target', axis=1)
Y_validation = df_valid["target"]

X_test = df_test.drop(labels='target', axis=1)
Y_test = df_test["target"]

print (len(df_train))
print (len(df_valid))
print (len(df_test))
# Out:
# 571
# 71
# 72

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 341    -0.213985     -0.082842       -0.209585  -0.158808        -0.104273
# 593     0.073408      0.004810        0.058601   0.046649        -0.164099
# 581     0.126147      0.031437        0.110324   0.092340        -0.156182
# 301    -0.078910      0.020303       -0.079739  -0.077874        -0.106981
# 380    -0.135231     -0.214056       -0.129977  -0.113930         0.246815
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 341         -0.036995       -0.010729            -0.129220       0.113324
# 593         -0.144882       -0.110271            -0.103334      -0.124091
# 581         -0.100009       -0.097752            -0.079322       0.046526
# 301         -0.009021       -0.048030            -0.089111      -0.015464
# 380          0.020732       -0.022960             0.032708       0.104233
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 341                0.178020  ...     -0.196343      -0.069489
# 593               -0.177807  ...      0.061230       0.151105
# 581               -0.207978  ...      0.110626       0.010618
# 301               -0.006479  ...     -0.099936      -0.069489
# 380                0.133580  ...     -0.121992      -0.137186
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 341        -0.179348   -0.129518         -0.059886           0.084733
# 593         0.046616    0.028031         -0.161415          -0.064541
# 581         0.104113    0.059928         -0.186202          -0.008019
# 301        -0.095280   -0.080929         -0.180734          -0.037319
# 380        -0.111217   -0.099411          0.189074          -0.011026
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 341         0.129322             -0.114798        0.016015
# 593        -0.035795             -0.099035       -0.018055
# 581        -0.033523             -0.069090        0.261484
# 301        -0.065326             -0.131808       -0.042530
# 380        -0.037930              0.059085        0.087176
#
#      fractal_dimension_worst
# 341                 0.093823
# 593                -0.099393
# 581                -0.074889
# 301                -0.041360
# 380                 0.053812
#
# [5 rows x 30 columns]

# %%
Y_train.head()
# Out:
# 341    0
# 593    1
# 581    1
# 301    0
# 380    0
# Name: target, dtype: uint8

# %%
#create a model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=48 ,activation='relu',input_shape=(30, )))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=48 ,activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=48 ,activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units= 1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 48)                1488
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 48)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                1176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy",tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# %%
epochs_hist = model.fit(X_train,Y_train, epochs=25,validation_data=(X_validation, Y_validation))
# Out:
# Train on 571 samples, validate on 71 samples
# Epoch 1/25
# 571/571 [==============================] - 3s 5ms/sample - loss: 0.6468 - accuracy: 0.7163 - recall_1: 0.4706 - precision_1: 0.9379 - val_loss: 0.6124 - val_accuracy: 0.9155 - val_recall_1: 0.8824 - val_precision_1: 0.9375
# Epoch 2/25
# 571/571 [==============================] - 0s 296us/sample - loss: 0.5634 - accuracy: 0.8862 - recall_1: 0.7958 - precision_1: 0.9746 - val_loss: 0.5162 - val_accuracy: 0.9296 - val_recall_1: 0.9118 - val_precision_1: 0.9394
# Epoch 3/25
# 571/571 [==============================] - 0s 308us/sample - loss: 0.4599 - accuracy: 0.9212 - recall_1: 0.8754 - precision_1: 0.9656 - val_loss: 0.4000 - val_accuracy: 0.9437 - val_recall_1: 0.9412 - val_precision_1: 0.9412
# Epoch 4/25
# 571/571 [==============================] - 0s 311us/sample - loss: 0.3492 - accuracy: 0.9387 - recall_1: 0.9066 - precision_1: 0.9704 - val_loss: 0.2951 - val_accuracy: 0.9577 - val_recall_1: 0.9412 - val_precision_1: 0.9697
# Epoch 5/25
# 571/571 [==============================] - 0s 299us/sample - loss: 0.2677 - accuracy: 0.9440 - recall_1: 0.9170 - precision_1: 0.9707 - val_loss: 0.2192 - val_accuracy: 0.9437 - val_recall_1: 0.9412 - val_precision_1: 0.9412
# Epoch 6/25
# 571/571 [==============================] - 0s 277us/sample - loss: 0.1993 - accuracy: 0.9562 - recall_1: 0.9481 - precision_1: 0.9648 - val_loss: 0.1714 - val_accuracy: 0.9437 - val_recall_1: 0.9412 - val_precision_1: 0.9412
# Epoch 7/25
# 571/571 [==============================] - 0s 277us/sample - loss: 0.1677 - accuracy: 0.9562 - recall_1: 0.9516 - precision_1: 0.9615 - val_loss: 0.1432 - val_accuracy: 0.9437 - val_recall_1: 0.9706 - val_precision_1: 0.9167
# Epoch 8/25
# 571/571 [==============================] - 0s 298us/sample - loss: 0.1450 - accuracy: 0.9650 - recall_1: 0.9619 - precision_1: 0.9686 - val_loss: 0.1221 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 9/25
# 571/571 [==============================] - 0s 305us/sample - loss: 0.1213 - accuracy: 0.9685 - recall_1: 0.9654 - precision_1: 0.9721 - val_loss: 0.1111 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 10/25
# 571/571 [==============================] - 0s 299us/sample - loss: 0.1085 - accuracy: 0.9685 - recall_1: 0.9654 - precision_1: 0.9721 - val_loss: 0.0988 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 11/25
# 571/571 [==============================] - 0s 338us/sample - loss: 0.1066 - accuracy: 0.9650 - recall_1: 0.9585 - precision_1: 0.9719 - val_loss: 0.0958 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 12/25
# 571/571 [==============================] - 0s 289us/sample - loss: 0.1011 - accuracy: 0.9685 - recall_1: 0.9619 - precision_1: 0.9754 - val_loss: 0.0875 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 13/25
# 571/571 [==============================] - 0s 287us/sample - loss: 0.0919 - accuracy: 0.9702 - recall_1: 0.9619 - precision_1: 0.9789 - val_loss: 0.0826 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 14/25
# 571/571 [==============================] - 0s 284us/sample - loss: 0.0979 - accuracy: 0.9685 - recall_1: 0.9585 - precision_1: 0.9788 - val_loss: 0.0811 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 15/25
# 571/571 [==============================] - 0s 293us/sample - loss: 0.0848 - accuracy: 0.9737 - recall_1: 0.9689 - precision_1: 0.9790 - val_loss: 0.0823 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 16/25
# 571/571 [==============================] - 0s 324us/sample - loss: 0.0822 - accuracy: 0.9685 - recall_1: 0.9654 - precision_1: 0.9721 - val_loss: 0.0708 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 17/25
# 571/571 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9761 - recall_1: 0.9670 - precision_1: 0.985 - 0s 296us/sample - loss: 0.0815 - accuracy: 0.9755 - recall_1: 0.9689 - precision_1: 0.9825 - val_loss: 0.0731 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 18/25
# 571/571 [==============================] - 0s 306us/sample - loss: 0.0819 - accuracy: 0.9737 - recall_1: 0.9689 - precision_1: 0.9790 - val_loss: 0.0669 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 19/25
# 571/571 [==============================] - 0s 341us/sample - loss: 0.0769 - accuracy: 0.9737 - recall_1: 0.9654 - precision_1: 0.9824 - val_loss: 0.0684 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 20/25
# 571/571 [==============================] - 0s 377us/sample - loss: 0.0789 - accuracy: 0.9702 - recall_1: 0.9689 - precision_1: 0.9722 - val_loss: 0.0690 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 21/25
# 571/571 [==============================] - 0s 324us/sample - loss: 0.0843 - accuracy: 0.9755 - recall_1: 0.9689 - precision_1: 0.9825 - val_loss: 0.0708 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 22/25
# 571/571 [==============================] - 0s 308us/sample - loss: 0.0726 - accuracy: 0.9772 - recall_1: 0.9758 - precision_1: 0.9792 - val_loss: 0.0642 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 23/25
# 571/571 [==============================] - 0s 377us/sample - loss: 0.0720 - accuracy: 0.9755 - recall_1: 0.9723 - precision_1: 0.9791 - val_loss: 0.0655 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 24/25
# 571/571 [==============================] - 0s 338us/sample - loss: 0.0690 - accuracy: 0.9755 - recall_1: 0.9689 - precision_1: 0.9825 - val_loss: 0.0612 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444
# Epoch 25/25
# 571/571 [==============================] - 0s 283us/sample - loss: 0.0613 - accuracy: 0.9807 - recall_1: 0.9758 - precision_1: 0.9860 - val_loss: 0.0612 - val_accuracy: 0.9718 - val_recall_1: 1.0000 - val_precision_1: 0.9444

# %%
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, Y_test)
print('test loss, test acc:', results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print('\n# Generate predictions')
predictions = model.predict(X_test)
#print (predictions[5:10], Y_test[5:10])
# Out:
# # Evaluate on test data
# 72/72 [==============================] - 0s 444us/sample - loss: 0.0534 - accuracy: 0.9861 - recall_1: 1.0000 - precision_1: 0.9714
# test loss, test acc: [0.05343846480051676, 0.9861111, 1.0, 0.9714286]
#
# # Generate predictions

# %%
confusion = tf.math.confusion_matrix(labels=Y_test, predictions=predictions,
                                              num_classes=2)

# %%
print (confusion)
# Out:
# tf.Tensor(
# [[38  0]
#  [33  1]], shape=(2, 2), dtype=int32)

# %%
#it's very dangerous (Error Type 2, have cancer but detected not detected)
