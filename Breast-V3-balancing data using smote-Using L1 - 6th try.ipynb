# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("breast.csv")

# %%
df.info() #check if there is missing data (null value)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
dataset = df.iloc[:, :-1] #drop the last column (error coloumn)

# %%
dataset.drop(labels='id', axis=1,inplace=True) #drop the id, because we don't need this, and no has no usefull and meaning for prediction

# %%
dataset["diagnosis"].value_counts() # imbalance data
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
######### VISUALIZATION #################

# %%
#Ploting relationship between radius_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "radius_mean", hist=False, rug=True)

# %%
#Ploting relationship between texture_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "texture_mean", hist=True, rug=True)

# %%
#Ploting relationship between perimeter_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "perimeter_mean", hist=True, rug=True)

# %%
#Ploting relationship between area_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "area_mean", hist=True, rug=True)

# %%
#Ploting relationship between smoothness_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "smoothness_mean", hist=True, rug=True)

# %%
#Ploting relationship between compactness_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "compactness_mean", hist=True, rug=True)

# %%
#Ploting relationship between concavity_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "concavity_mean", hist=True, rug=True)

# %%
#Ploting relationship between concave point_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "concave points_mean", hist=True, rug=True)

# %%
#Ploting relationship between symetry_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "symmetry_mean", hist=True, rug=True)

# %%
#Ploting relationship between fractal_dimension_mean and diagnosis 
#g = sns.FacetGrid(df, col='diagnosis', hue='diagnosis')
#g.map(sns.distplot, "fractal_dimension_mean", hist=True, rug=True)

# %%
### It seems almost all data approximately symetry (base on display for each features), therefore no need to log

# %%
#sns.pairplot(df,hue="diagnosis",vars = ["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean"])

# %%
## Looking for correlation between each features


#Explore correlations
#plt.rcParams['figure.figsize']=(15,20)
#sns.set(font_scale=1.4)
#sns.heatmap(df.drop('diagnosis', axis=1).drop('id',axis=1).corr(), cmap='coolwarm',annot=True)

# %%
Y = pd.get_dummies(dataset["diagnosis"],drop_first=True)  #convert Malign to 1 and Benign to 0

# %%
Y.rename(columns={"M": "target"},inplace=True)  #rename for convinient name only
Y.head()
# Out:
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
X = dataset.drop(labels='diagnosis', axis=1) #drop the diagnosis,because we have changed B/M to M's coloumn (numerical_number)

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
df_norm = (X - X.mean()) / (X.max() - X.min())
X_norm = df_norm.copy()
Y_norm = Y.copy()
df_norm = pd.concat([df_norm, Y], axis=1)

# %%
df_norm.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.182815     -0.301307        0.213053   0.146813         0.198968
# 1     0.304923     -0.051392        0.282848   0.284671        -0.104905
# 2     0.263274      0.066295        0.262808   0.232497         0.119524
# 3    -0.128132      0.036874       -0.099434  -0.114014         0.416536
# 4     0.291671     -0.167388        0.298051   0.272369         0.035567
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.531437        0.495081             0.487976       0.306758
# 1         -0.078833       -0.004450             0.105621       0.000193
# 2          0.170416        0.254453             0.392549       0.129991
# 3          0.550761        0.357546             0.279726       0.396657
# 4          0.087292        0.255859             0.275253      -0.001323
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.335139  ...      -0.222474         0.385173    0.279792
# 1               -0.129057  ...      -0.060427         0.256680    0.264308
# 2               -0.059132  ...      -0.003924         0.225304    0.203602
# 3                0.729621  ...       0.021929        -0.041791   -0.076898
# 4               -0.083564  ...      -0.240065         0.223810    0.170669
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.351207              0.518192        0.335156
# 1          -0.024432              0.245339       -0.029717
# 2           0.142341              0.441216        0.140399
# 3           0.331239              0.491044        0.736693
# 4           0.102086              0.164583       -0.105806
# ..               ...                   ...             ...
# 564         0.110632              0.367676       -0.165731
# 565         0.039386              0.165614       -0.064805
# 566         0.054402              0.093449       -0.134586
# 567         0.532357              0.516817        0.233835
# 568        -0.217403             -0.393836       -0.005866
#
#      fractal_dimension_worst
# 0                   0.229268
# 1                   0.033282
# 2                   0.023837
# 3                   0.584115
# 4                  -0.047001
# ..                       ...
# 564                -0.083929
# 565                -0.115281
# 566                -0.037687
# 567                 0.262719
# 568                -0.088914
#
# [569 rows x 30 columns]

# %%
Y_norm
# Out:
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 564       1
# 565       1
# 566       1
# 567       1
# 568       0
#
# [569 rows x 1 columns]

# %%
#Balancing data 
from imblearn.over_sampling import SMOTE

sm =SMOTE(random_state=0)
X_res , Y_res = sm.fit_resample(X_norm,Y_norm)
# Out:
# Using TensorFlow backend.

# %%
my_dataset = X_res.copy()

# %%
my_dataset=pd.concat([my_dataset, Y_res], axis=1)

# %%
my_dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.182815     -0.301307        0.213053   0.146813         0.198968
# 1     0.304923     -0.051392        0.282848   0.284671        -0.104905
# 2     0.263274      0.066295        0.262808   0.232497         0.119524
# 3    -0.128132      0.036874       -0.099434  -0.114014         0.416536
# 4     0.291671     -0.167388        0.298051   0.272369         0.035567
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.531437        0.495081             0.487976       0.306758
# 1         -0.078833       -0.004450             0.105621       0.000193
# 2          0.170416        0.254453             0.392549       0.129991
# 3          0.550761        0.357546             0.279726       0.396657
# 4          0.087292        0.255859             0.275253      -0.001323
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.335139  ...      -0.222474         0.385173    0.279792
# 1               -0.129057  ...      -0.060427         0.256680    0.264308
# 2               -0.059132  ...      -0.003924         0.225304    0.203602
# 3                0.729621  ...       0.021929        -0.041791   -0.076898
# 4               -0.083564  ...      -0.240065         0.223810    0.170669
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0          0.196998           0.399079         0.351207              0.518192
# 1         -0.056585          -0.065649        -0.024432              0.245339
# 2          0.079452           0.165163         0.142341              0.441216
# 3          0.511335           0.593799         0.331239              0.491044
# 4          0.033226          -0.047797         0.102086              0.164583
#
#    symmetry_worst  fractal_dimension_worst  target
# 0        0.335156                 0.229268       1
# 1       -0.029717                 0.033282       1
# 2        0.140399                 0.023837       1
# 3        0.736693                 0.584115       1
# 4       -0.105806                -0.047001       1
#
# [5 rows x 31 columns]

# %%
np.random.seed(13) # choose this number because result for 1 nor 0 equal
shuffle_df = my_dataset.reindex(np.random.permutation(my_dataset.index))

# %%
shuffle_df.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 613     0.234997     -0.040667        0.240357   0.211980         0.145592
# 156     0.168144      0.049048        0.175737   0.130991         0.136677
# 700    -0.006906      0.111707        0.023890  -0.022763         0.124685
# 627     0.156592     -0.076174        0.151122   0.120813         0.021036
# 233     0.302083      0.288142        0.293214   0.281701        -0.043065
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 613          0.229300        0.271174             0.287340       0.043834
# 156          0.190660        0.226571             0.280720       0.080496
# 700          0.378805        0.320991             0.173724       0.126952
# 627          0.010169        0.080890             0.152598      -0.008048
# 233          0.009383        0.156047             0.171376      -0.183646
#
#      fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 613                0.064870  ...      -0.042747         0.287024    0.255966
# 156               -0.023960  ...      -0.015118         0.127690    0.103573
# 700                0.259857  ...       0.143360         0.025426   -0.037819
# 627               -0.133881  ...      -0.030886         0.119954    0.087114
# 233               -0.144853  ...       0.311908         0.276103    0.243663
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 613          0.109813           0.196180         0.216368
# 156          0.062282           0.092688         0.068779
# 700          0.183233           0.489558         0.372775
# 627          0.042149          -0.008640         0.065968
# 233         -0.066490           0.021184         0.113747
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  target
# 613              0.298969        0.058878                 0.122959       1
# 156              0.126783       -0.086291                -0.043066       1
# 700              0.384640        0.106132                 0.349104       1
# 627              0.223706        0.035902                -0.017101       1
# 233              0.143278       -0.091416                -0.004367       1
#
# [5 rows x 31 columns]

# %%
shuffle_df["target"].value_counts() # already balance
# Out:
# 1    357
# 0    357
# Name: target, dtype: int64

# %%
#n_train 
#80% for train
#10% for validation
#10% for testing
ukuran_train=0.8
ukuran_validation=0.10

total = len(shuffle_df)
n_train = int (ukuran_train*total)
n_validation = int (ukuran_validation*total)
n_test = total-n_train-n_validation

#print (total)
#print (n_train)
#print (n_validation)
#print (n_test)

# %%
#split train_test
df_train = shuffle_df[0:n_train]
df_valid = shuffle_df[n_train:n_train+n_validation]
df_test= shuffle_df[n_train+n_validation:]

# %%
(df_train["target"]==1).sum()
# Out:
# 285

# %%
(df_train["target"]==0).sum()
# Out:
# 286

# %%
X_train = df_train.drop(labels='target', axis=1)
Y_train = df_train["target"]

X_validation = df_valid.drop(labels='target', axis=1)
Y_validation = df_valid["target"]

X_test = df_test.drop(labels='target', axis=1)
Y_test = df_test["target"]

print (len(df_train))
print (len(df_valid))
print (len(df_test))
# Out:
# 571
# 71
# 72

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 613     0.234997     -0.040667        0.240357   0.211980         0.145592
# 156     0.168144      0.049048        0.175737   0.130991         0.136677
# 700    -0.006906      0.111707        0.023890  -0.022763         0.124685
# 627     0.156592     -0.076174        0.151122   0.120813         0.021036
# 233     0.302083      0.288142        0.293214   0.281701        -0.043065
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 613          0.229300        0.271174             0.287340       0.043834
# 156          0.190660        0.226571             0.280720       0.080496
# 700          0.378805        0.320991             0.173724       0.126952
# 627          0.010169        0.080890             0.152598      -0.008048
# 233          0.009383        0.156047             0.171376      -0.183646
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 613                0.064870  ...      0.306455      -0.042747
# 156               -0.023960  ...      0.149442      -0.015118
# 700                0.259857  ...     -0.033995       0.143360
# 627               -0.133881  ...      0.130896      -0.030886
# 233               -0.144853  ...      0.291740       0.311908
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 613         0.287024    0.255966          0.109813           0.196180
# 156         0.127690    0.103573          0.062282           0.092688
# 700         0.025426   -0.037819          0.183233           0.489558
# 627         0.119954    0.087114          0.042149          -0.008640
# 233         0.276103    0.243663         -0.066490           0.021184
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 613         0.216368              0.298969        0.058878
# 156         0.068779              0.126783       -0.086291
# 700         0.372775              0.384640        0.106132
# 627         0.065968              0.223706        0.035902
# 233         0.113747              0.143278       -0.091416
#
#      fractal_dimension_worst
# 613                 0.122959
# 156                -0.043066
# 700                 0.349104
# 627                -0.017101
# 233                -0.004367
#
# [5 rows x 30 columns]

# %%
Y_train.head()
# Out:
# 613    1
# 156    1
# 700    1
# 627    1
# 233    1
# Name: target, dtype: uint8

# %%
#create a model
nilai_regulasi = tf.keras.regularizers.l1(0)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=48,activation='relu',input_shape=(30, )))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=48 ,activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=18 ,activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units= 1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_215 (Dense)            (None, 48)                1488
# _________________________________________________________________
# dropout_171 (Dropout)        (None, 48)                0
# _________________________________________________________________
# dense_216 (Dense)            (None, 48)                2352
# _________________________________________________________________
# dropout_172 (Dropout)        (None, 48)                0
# _________________________________________________________________
# dense_217 (Dense)            (None, 18)                882
# _________________________________________________________________
# dropout_173 (Dropout)        (None, 18)                0
# _________________________________________________________________
# dense_218 (Dense)            (None, 1)                 19
# =================================================================
# Total params: 4,741
# Trainable params: 4,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
epochs_hist = model.fit(X_train,Y_train, epochs=250,validation_data=(X_validation, Y_validation))
# Out:
# Train on 571 samples, validate on 71 samples
# Epoch 1/250
# 571/571 [==============================] - 1s 960us/sample - loss: 0.6813 - accuracy: 0.6025 - val_loss: 0.6540 - val_accuracy: 0.8592
# Epoch 2/250
# 571/571 [==============================] - 0s 89us/sample - loss: 0.6215 - accuracy: 0.8511 - val_loss: 0.5522 - val_accuracy: 0.9296
# Epoch 3/250
# 571/571 [==============================] - 0s 88us/sample - loss: 0.4941 - accuracy: 0.9054 - val_loss: 0.3776 - val_accuracy: 0.9577
# Epoch 4/250
# 571/571 [==============================] - 0s 88us/sample - loss: 0.3391 - accuracy: 0.9299 - val_loss: 0.2102 - val_accuracy: 0.9718
# Epoch 5/250
# 571/571 [==============================] - 0s 88us/sample - loss: 0.2044 - accuracy: 0.9492 - val_loss: 0.1130 - val_accuracy: 0.9859
# Epoch 6/250
# 571/571 [==============================] - 0s 95us/sample - loss: 0.1427 - accuracy: 0.9615 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 7/250
# 571/571 [==============================] - 0s 86us/sample - loss: 0.1164 - accuracy: 0.9650 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 8/250
# 571/571 [==============================] - 0s 89us/sample - loss: 0.0973 - accuracy: 0.9650 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 9/250
# 571/571 [==============================] - 0s 89us/sample - loss: 0.0939 - accuracy: 0.9755 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 10/250
# 571/571 [==============================] - 0s 95us/sample - loss: 0.0920 - accuracy: 0.9720 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 11/250
# 571/571 [==============================] - 0s 95us/sample - loss: 0.0813 - accuracy: 0.9720 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 12/250
# 571/571 [==============================] - 0s 88us/sample - loss: 0.0868 - accuracy: 0.9720 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 13/250
# 571/571 [==============================] - 0s 98us/sample - loss: 0.0758 - accuracy: 0.9720 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 14/250
# 571/571 [==============================] - 0s 86us/sample - loss: 0.0694 - accuracy: 0.9807 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 15/250
# 571/571 [==============================] - 0s 86us/sample - loss: 0.0643 - accuracy: 0.9807 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 16/250
# 571/571 [==============================] - 0s 88us/sample - loss: 0.0583 - accuracy: 0.9825 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 17/250
# 571/571 [==============================] - 0s 95us/sample - loss: 0.0712 - accuracy: 0.9790 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 18/250
# 571/571 [==============================] - 0s 86us/sample - loss: 0.
# 571/571 [==============================] - 0s 93us/sample - loss: 3.7883e-04 - accuracy: 1.0000 - val_loss: 2.2171e-04 - val_accuracy: 1.0000
# Epoch 235/250
# 571/571 [==============================] - 0s 98us/sample - loss: 0.0063 - accuracy: 0.9982 - val_loss: 6.1817e-04 - val_accuracy: 1.0000
# Epoch 236/250
# 571/571 [==============================] - 0s 95us/sample - loss: 5.7637e-04 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9859
# Epoch 237/250
# 571/571 [==============================] - 0s 95us/sample - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 238/250
# 571/571 [==============================] - 0s 100us/sample - loss: 0.0051 - accuracy: 0.9965 - val_loss: 2.6648e-04 - val_accuracy: 1.0000
# Epoch 239/250
# 571/571 [==============================] - 0s 98us/sample - loss: 0.0023 - accuracy: 0.9982 - val_loss: 0.0104 - val_accuracy: 0.9859
# Epoch 240/250
# 571/571 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 1.00 - 0s 91us/sample - loss: 0.0057 - accuracy: 0.9965 - val_loss: 3.0013e-04 - val_accuracy: 1.0000
# Epoch 241/250
# 571/571 [==============================] - 0s 95us/sample - loss: 8.1370e-04 - accuracy: 1.0000 - val_loss: 4.0365e-04 - val_accuracy: 1.0000
# Epoch 242/250
# 571/571 [==============================] - 0s 105us/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.0144e-04 - val_accuracy: 1.0000
# Epoch 243/250
# 571/571 [==============================] - 0s 91us/sample - loss: 0.0021 - accuracy: 0.9982 - val_loss: 1.9006e-04 - val_accuracy: 1.0000
# Epoch 244/250
# 571/571 [==============================] - 0s 84us/sample - loss: 0.0038 - accuracy: 0.9982 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 245/250
# 571/571 [==============================] - 0s 86us/sample - loss: 0.0033 - accuracy: 0.9965 - val_loss: 0.0537 - val_accuracy: 0.9859
# Epoch 246/250
# 571/571 [==============================] - 0s 82us/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 247/250
# 571/571 [==============================] - 0s 95us/sample - loss: 6.0328e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 248/250
# 571/571 [==============================] - 0s 82us/sample - loss: 8.4150e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 249/250
# 571/571 [==============================] - 0s 79us/sample - loss: 4.8108e-04 - accuracy: 1.0000 - val_loss: 5.6745e-04 - val_accuracy: 1.0000
# Epoch 250/250
# 571/571 [==============================] - 0s 77us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.6029e-04 - val_accuracy: 1.0000

# %%
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, Y_test)
print('test loss, test acc:', results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print('\n# Generate predictions')
predictions = model.predict(X_test)
#print (predictions[5:10], Y_test[5:10])
# Out:
# # Evaluate on test data
# 72/72 [==============================] - 0s 97us/sample - loss: 0.7351 - accuracy: 0.9583
# test loss, test acc: [0.7351041187920452, 0.9583333]
#
# # Generate predictions

# %%
confusion = tf.math.confusion_matrix(labels=Y_test, predictions=predictions,
                                              num_classes=2)

# %%
print (confusion)
# Out:
# tf.Tensor(
# [[38  0]
#  [ 5 29]], shape=(2, 2), dtype=int32)

# %%
#it's very dangerous (Error Type 2, have cancer but not detected)
